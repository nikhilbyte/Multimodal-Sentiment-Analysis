# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/MVSA/MVSA-Single.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: MVSA_Single/data/3347.txt
#   inflating: MVSA_Single/data/3348.jpg
#   inflating: MVSA_Single/data/3348.txt
#   inflating: MVSA_Single/data/3349.jpg
#  extracting: MVSA_Single/data/3349.txt
#   inflating: MVSA_Single/data/335.jpg
#   inflating: MVSA_Single/data/335.txt
#   inflating: MVSA_Single/data/3350.jpg
#  extracting: MVSA_Single/data/3350.txt
#   inflating: MVSA_Single/data/3351.jpg
#   inflating: MVSA_Single/data/3351.txt
#   inflating: MVSA_Single/data/3352.jpg
#   inflating: MVSA_Single/data/3352.txt
#   inflating: MVSA_Single/data/3353.jpg
#  extracting: MVSA_Single/data/3353.txt
#   inflating: MVSA_Single/data/3354.jpg
#   inflating: MVSA_Single/data/3354.txt
#   inflating: MVSA_Single/data/3355.jpg
#  extracting: MVSA_Single/data/3355.txt
#   inflating: MVSA_Single/data/3356.jpg
#   inflating: MVSA_Single/data/3356.txt
#   inflating: MVSA_Single/data/3357.jpg
#   inflating: MVSA_Single/data/3357.txt
#   inflating: MVSA_Single/data/3358.jpg
#   inflating: MVSA_Single/data/3358.txt
#   inflating: MVSA_Single/data/3359.jpg
#   inflating: MVSA_Single/data/3359.txt
#   inflating: MVSA_Single/data/336.jpg
#  extracting: MVSA_Single/data/336.txt
#   inflating: MVSA_Single/data/3360.jpg
#   inflating: MVSA_Single/data/3360.txt
#   inflating: MVSA_Single/data/3361.jpg
#  extracting: MVSA_Single/data/3361.txt
#   inflating: MVSA_Single/data/3362.jpg
#  extracting: MVSA_Single/data/3362.txt
#   inflating: MVSA_Single/data/3363.jpg
#  extracting: MVSA_Single/data/3363.txt
#   inflating: MVSA_Single/data/3364.jpg
#  extracting: MVSA_Single/data/3364.txt
#   inflating: MVSA_Single/data/3365.jpg
#  extracting: MVSA_Single/data/3365.txt
#   inflating: MVSA_Single/data/3366.jpg
#   inflating: MVSA_Single/data/3366.txt
#   inflating: MVSA_Single/data/3367.jpg
#  extracting: MVSA_Single/data/3367.txt
#   inflating: MVSA_Single/data/3368.jpg
#   inflating: MVSA_Single/data/3368.txt
#   inflating: MVSA_Single/data/3369.jpg
#   inflating: MVSA_Single/data/3369.txt
#   inflating: MVSA_Single/data/337.jpg
#  extracting: MVSA_Single/data/337.txt
#   inflating: MVSA_Single/data/3370.jpg
#   inflating: MVSA_Single/data/3370.txt
#   inflating: MVSA_Single/data/3371.jpg
#   inflating: MVSA_Single/data/3371.txt
#   inflating: MVSA_Single/data/3372.jpg
#   inflating: MVSA_Single/data/3372.txt
#   inflating: MVSA_Single/data/3373.jpg
#   inflating: MVSA_Single/data/3373.txt
#   inflating: MVSA_Single/data/3374.jpg
#   inflating: MVSA_Single/data/3374.txt
#   inflating: MVSA_Single/data/3375.jpg
#   inflating: MVSA_Single/data/3375.txt
#   inflating: MVSA_Single/data/3376.jpg
#   inflating: MVSA_Single/data/3376.txt
#   inflating: MVSA_Single/data/3377.jpg
#   inflating: MVSA_Single/data/3377.txt
#   inflating: MVSA_Single/data/3378.jpg
#   inflating: MVSA_Single/data/3378.txt
#   inflating: MVSA_Single/data/3379.jpg
#  extracting: MVSA_Single/data/3379.txt
#   inflating: MVSA_Single/data/338.jpg
#   inflating: MVSA_Single/data/338.txt
#   inflating: MVSA_Single/data/3380.jpg
#   inflating: MVSA_Single/data/3380.txt
#   inflating: MVSA_Single/data/3381.jpg
#  extracting: MVSA_Single/data/3381.txt
#   inflating: MVSA_Single/data/3382.jpg
#  extracting: MVSA_Single/data/3382.txt
#   inflating: MVSA_Single/data/3383.jpg
#   inflating: MVSA_Single/data/3383.txt
#   inflating: MVSA_Single/data/3384.jpg
#   inflating: MVSA_Single/data/3384.txt
#   inflating: MVSA_Single/data/3385.jpg
#   inflating: MVSA_Single/data/3385.txt
#   inflating: MVSA_Single/data/3386.jpg
#   inflating: MVSA_Single/data/3386.txt
#   inflating: MVSA_Single/data/3387.jpg
#  extracting: MVSA_Single/data/3387.txt
#   inflating: MVSA_Single/data/3388.jpg
#   inflating: MVSA_Single/data/3388.txt
#   inflating: MVSA_Single/data/3389.jpg
#   inflating: MVSA_Single/data/3389.txt
#   inflating: MVSA_Single/data/339.jpg
#   inflating: MVSA_Single/data/339.txt
#   inflating: MVSA_Single/data/3390.jpg
#   inflating: MVSA_Single/data/3390.txt
#   inflating: MVSA_Single/data/3391.jpg
#   inflating: MVSA_Single/data/3391.txt
#   inflating: MVSA_Single/data/3392.jpg
#  extracting: MVSA_Single/data/3392.txt
#   inflating: MVSA_Single/data/3393.jpg
#   inflating: MVSA_Single/data/3393.txt
#   inflating: MVSA_Single/data/3394.jpg
#  extracting: MVSA_Single/data/3394.txt
#   inflating: MVSA_Single/data/3395.jpg
#   inflating: MVSA_Single/data/3395.txt
#   inflating: MVSA_Single/data/3396.jpg
#   inflating: MVSA_Single/data/3396.txt
#   inflating: MVSA_Single/data/3397.jpg
#   inflating: MVSA_Single/data/3397.txt
#   inflating: MVSA_Single/data/3398.jpg
#  extracting: MVSA_Single/data/3398.txt
#   inflating: MVSA_Single/data/3399.jpg
#  extracting: MVSA_Single/data/3399.txt
#   inflating: MVSA_Single/data/34.jpg
#  extracting: MVSA_Single/data/34.txt
#   inflating: MVSA_Single/data/340.jpg
#   inflating: MVSA_Single/data/340.txt
#   inflating: MVSA_Single/data/3400.jpg
#   inflating: MVSA_Single/data/3400.txt
#   inflating: MVSA_Single/data/3401.jpg
#   inflating: MVSA_Single/data/3401.txt
#   inflating: MVSA_Single/data/3402.jpg
#   inflating: MVSA_Single/data/3402.txt
#   inflating: MVSA_Single/data/3403.jpg
#   inflating: MVSA_Single/data/3403.txt
#   inflating: MVSA_Single/data/3404.jpg
#  extracting: MVSA_Single/data/3404.txt
#   inflating: MVSA_Single/data/3405.jpg
#   inflating: MVSA_Single/data/3405.txt
#   inflating: MVSA_Single/data/3406.jpg
#  extracting: MVSA_Single/data/3406.txt
#   inflating: MVSA_Single/data/3407.jpg
#  extracting: MVSA_Single/data/3407.txt
#   inflating: MVSA_Single/data/3408.jpg
#   inflating: MVSA_Single/data/3408.txt
#   inflating: MVSA_Single/data/3409.jpg
#  extracting: MVSA_Single/data/3409.txt
#   inflating: MVSA_Single/data/341.jpg
#   inflating: MVSA_Single/data/341.txt
#   inflating: MVSA_Single/data/3410.jpg
#   inflating: MVSA_Single/data/3410.txt
#   inflating: MVSA_Single/data/3411.jpg
#   inflating: MVSA_Single/data/3411.txt
#   inflating: MVSA_Single/data/3412.jpg
#  extracting: MVSA_Single/data/3412.txt
#   inflating: MVSA_Single/data/3413.jpg
#  extracting: MVSA_Single/data/3413.txt
#   inflating: MVSA_Single/data/3414.jpg
#   inflating: MVSA_Single/data/3414.txt
#   inflating: MVSA_Single/data/3415.jpg
#   inflating: MVSA_Single/data/3415.txt
#   inflating: MVSA_Single/data/3416.jpg
#  extracting: MVSA_Single/data/3416.txt
#   inflating: MVSA_Single/data/3417.jpg
#  extracting: MVSA_Single/data/3417.txt
#   inflating: MVSA_Single/data/3418.jpg
#   inflating: MVSA_Single/data/3418.txt
#   inflating: MVSA_Single/data/3419.jpg
#   inflating: MVSA_Single/data/3419.txt
#   inflating: MVSA_Single/data/342.jpg
#   inflating: MVSA_Single/data/342.txt
#   inflating: MVSA_Single/data/3420.jpg
#   inflating: MVSA_Single/data/3420.txt
#   inflating: MVSA_Single/data/3421.jpg
#   inflating: MVSA_Single/data/3421.txt
#   inflating: MVSA_Single/data/3422.jpg
#   inflating: MVSA_Single/data/3422.txt
#   inflating: MVSA_Single/data/3423.jpg
#   inflating: MVSA_Single/data/3423.txt
#   inflating: MVSA_Single/data/3424.jpg
#  extracting: MVSA_Single/data/3424.txt
#   inflating: MVSA_Single/data/3425.jpg
#   inflating: MVSA_Single/data/3425.txt
#   inflating: MVSA_Single/data/3426.jpg
#   inflating: MVSA_Single/data/3426.txt
#   inflating: MVSA_Single/data/3427.jpg
#   inflating: MVSA_Single/data/3427.txt
#   inflating: MVSA_Single/data/3428.jpg
#  extracting: MVSA_Single/data/3428.txt
#   inflating: MVSA_Single/data/3429.jpg
#   inflating: MVSA_Single/data/3429.txt
#   inflating: MVSA_Single/data/343.jpg
#   inflating: MVSA_Single/data/343.txt
#   inflating: MVSA_Single/data/3430.jpg
#   inflating: MVSA_Single/data/3430.txt
#   inflating: MVSA_Single/data/3431.jpg
#   inflating: MVSA_Single/data/3431.txt
#   inflating: MVSA_Single/data/3432.jpg
#  extracting: MVSA_Single/data/3432.txt
#   inflating: MVSA_Single/data/3433.jpg
#   inflating: MVSA_Single/data/3433.txt
#   inflating: MVSA_Single/data/3434.jpg
#   inflating: MVSA_Single/data/3434.txt
#   inflating: MVSA_Single/data/3435.jpg
#   inflating: MVSA_Single/data/3435.txt
#   inflating: MVSA_Single/data/3436.jpg
#  extracting: MVSA_Single/data/3436.txt
#   inflating: MVSA_Single/data/3437.jpg
#   inflating: MVSA_Single/data/3437.txt
#   inflating: MVSA_Single/data/3439.jpg
#  extracting: MVSA_Single/data/3439.txt
#   inflating: MVSA_Single/data/344.jpg
#   inflating: MVSA_Single/data/344.txt
#   inflating: MVSA_Single/data/3440.jpg
#   inflating: MVSA_Single/data/3440.txt
#   inflating: MVSA_Single/data/3441.jpg
#   inflating: MVSA_Single/data/3441.txt
#   inflating: MVSA_Single/data/3442.jpg
#   inflating: MVSA_Single/data/3442.txt
#   inflating: MVSA_Single/data/3443.jpg
#  extracting: MVSA_Single/data/3443.txt
#   inflating: MVSA_Single/data/3444.jpg
#   inflating: MVSA_Single/data/3444.txt
#   inflating: MVSA_Single/data/3445.jpg
#  extracting: MVSA_Single/data/3445.txt
#   inflating: MVSA_Single/data/3446.jpg
#  extracting: MVSA_Single/data/3446.txt
#   inflating: MVSA_Single/data/3447.jpg
#  extracting: MVSA_Single/data/3447.txt
#   inflating: MVSA_Single/data/3448.jpg
#  extracting: MVSA_Single/data/3448.txt
#   inflating: MVSA_Single/data/3449.jpg
#  extracting: MVSA_Single/data/3449.txt
#   inflating: MVSA_Single/data/345.jpg
#   inflating: MVSA_Single/data/345.txt
#   inflating: MVSA_Single/data/3450.jpg
#  extracting: MVSA_Single/data/3450.txt
#   inflating: MVSA_Single/data/3451.jpg
#  extracting: MVSA_Single/data/3451.txt
#   inflating: MVSA_Single/data/3452.jpg
#  extracting: MVSA_Single/data/3452.txt
#   inflating: MVSA_Single/data/3453.jpg
#   inflating: MVSA_Single/data/3453.txt
#   inflating: MVSA_Single/data/3454.jpg
#   inflating: MVSA_Single/data/3454.txt
#   inflating: MVSA_Single/data/3455.jpg
#   inflating: MVSA_Single/data/3455.txt
#   inflating: MVSA_Single/data/3456.jpg
#   inflating: MVSA_Single/data/3456.txt
#   inflating: MVSA_Single/data/3457.jpg
#   inflating: MVSA_Single/data/3457.txt
#   inflating: MVSA_Single/data/3458.jpg
#   inflating: MVSA_Single/data/3458.txt
#   inflating: MVSA_Single/data/3459.jpg
#   inflating: MVSA_Single/data/3459.txt
#   inflating: MVSA_Single/data/346.jpg
#  extracting: MVSA_Single/data/346.txt
#   inflating: MVSA_Single/data/3460.jpg
#  extracting: MVSA_Single/data/3460.txt
#   inflating: MVSA_Single/data/3461.jpg
#   inflating: MVSA_Single/data/3461.txt
#   inflating: MVSA_Single/data/3462.jpg
#   inflating: MVSA_Single/data/3462.txt
#   inflating: MVSA_Single/data/3463.jpg
#  extracting: MVSA_Single/data/3463.txt
#   inflating: MVSA_Single/data/3464.jpg
#   inflating: MVSA_Single/data/3464.txt
#   inflating: MVSA_Single/data/3465.jpg
#  extracting: MVSA_Single/data/3465.txt
#   inflating: MVSA_Single/data/3466.jpg
#   inflating: MVSA_Single/data/3466.txt
#   inflating: MVSA_Single/data/3467.jpg
#   inflating: MVSA_Single/data/3467.txt
#   inflating: MVSA_Single/data/3468.jpg
#  extracting: MVSA_Single/data/3468.txt
#   inflating: MVSA_Single/data/3469.jpg
#   inflating: MVSA_Single/data/3469.txt
#   inflating: MVSA_Single/data/347.jpg
#   inflating: MVSA_Single/data/347.txt
#   inflating: MVSA_Single/data/3470.jpg
#  extracting: MVSA_Single/data/3470.txt
#   inflating: MVSA_Single/data/3472.jpg
#   inflating: MVSA_Single/data/3472.txt
#   inflating: MVSA_Single/data/3473.jpg
#  extracting: MVSA_Single/data/3473.txt
#   inflating: MVSA_Single/data/3474.jpg
#  extracting: MVSA_Single/data/3474.txt
#   inflating: MVSA_Single/data/3475.jpg
#  extracting: MVSA_Single/data/3475.txt
#   inflating: MVSA_Single/data/3476.jpg
#  extracting: MVSA_Single/data/3476.txt
#   inflating: MVSA_Single/data/3477.jpg
#   inflating: MVSA_Single/data/3477.txt
#   inflating: MVSA_Single/data/3478.jpg
#   inflating: MVSA_Single/data/3478.txt
#   inflating: MVSA_Single/data/3479.jpg
#   inflating: MVSA_Single/data/3479.txt
#   inflating: MVSA_Single/data/348.jpg
#  extracting: MVSA_Single/data/348.txt
#   inflating: MVSA_Single/data/3480.jpg
#   inflating: MVSA_Single/data/3480.txt
#   inflating: MVSA_Single/data/3481.jpg
#   inflating: MVSA_Single/data/3481.txt
#   inflating: MVSA_Single/data/3482.jpg
#   inflating: MVSA_Single/data/3482.txt
#   inflating: MVSA_Single/data/3483.jpg
#  extracting: MVSA_Single/data/3483.txt
#   inflating: MVSA_Single/data/3484.jpg
#  extracting: MVSA_Single/data/3484.txt
#   inflating: MVSA_Single/data/3485.jpg
#  extracting: MVSA_Single/data/3485.txt
#   inflating: MVSA_Single/data/3486.jpg
#   inflating: MVSA_Single/data/3486.txt
#   inflating: MVSA_Single/data/3487.jpg
#   inflating: MVSA_Single/data/3487.txt
#   inflating: MVSA_Single/data/3488.jpg
#   inflating: MVSA_Single/data/3488.txt
#   inflating: MVSA_Single/data/3489.jpg
#  extracting: MVSA_Single/data/3489.txt
#   inflating: MVSA_Single/data/349.jpg
#  extracting: MVSA_Single/data/349.txt
#   inflating: MVSA_Single/data/3490.jpg
#   inflating: MVSA_Single/data/3490.txt
#   inflating: MVSA_Single/data/3491.jpg
#   inflating: MVSA_Single/data/3491.txt
#   inflating: MVSA_Single/data/3492.jpg
#  extracting: MVSA_Single/data/3492.txt
#   inflating: MVSA_Single/data/3493.jpg
#  extracting: MVSA_Single/data/3493.txt
#   inflating: MVSA_Single/data/3494.jpg
#  extracting: MVSA_Single/data/3494.txt
#   inflating: MVSA_Single/data/3495.jpg
#  extracting: MVSA_Single/data/3495.txt
#   inflating: MVSA_Single/data/3496.jpg
#   inflating: MVSA_Single/data/3496.txt
#   inflating: MVSA_Single/data/3497.jpg
#   inflating: MVSA_Single/data/3497.txt
#   inflating: MVSA_Single/data/3498.jpg
#   inflating: MVSA_Single/data/3498.txt
#   inflating: MVSA_Single/data/3499.jpg
#  extracting: MVSA_Single/data/3499.txt
#   inflating: MVSA_Single/data/35.jpg
#  extracting: MVSA_Single/data/35.txt
#   inflating: MVSA_Single/data/350.jpg
#  extracting: MVSA_Single/data/350.txt
#   inflating: MVSA_Single/data/3500.jpg
#  extracting: MVSA_Single/data/3500.txt
#   inflating: MVSA_Single/data/3501.jpg
#  extracting: MVSA_Single/data/3501.txt
#   inflating: MVSA_Single/data/3502.jpg
#  extracting: MVSA_Single/data/3502.txt
#   inflating: MVSA_Single/data/3503.jpg
#   inflating: MVSA_Single/data/3503.txt
#   inflating: MVSA_Single/data/3504.jpg
#   inflating: MVSA_Single/data/3504.txt
#   inflating: MVSA_Single/data/3505.jpg
#   inflating: MVSA_Single/data/3505.txt
#   inflating: MVSA_Single/data/3506.jpg
#   inflating: MVSA_Single/data/3506.txt
#   inflating: MVSA_Single/data/3507.jpg
#   inflating: MVSA_Single/data/3507.txt
#   inflating: MVSA_Single/data/3508.jpg
#  extracting: MVSA_Single/data/3508.txt
#   inflating: MVSA_Single/data/3509.jpg
#  extracting: MVSA_Single/data/3509.txt
#   inflating: MVSA_Single/data/351.jpg
#  extracting: MVSA_Single/data/351.txt
#   inflating: MVSA_Single/data/3510.jpg
#  extracting: MVSA_Single/data/3510.txt
#   inflating: MVSA_Single/data/3511.jpg
#  extracting: MVSA_Single/data/3511.txt
#   inflating: MVSA_Single/data/3512.jpg
#   inflating: MVSA_Single/data/3512.txt
#   inflating: MVSA_Single/data/3513.jpg
#  extracting: MVSA_Single/data/3513.txt
#   inflating: MVSA_Single/data/3515.jpg
#   inflating: MVSA_Single/data/3515.txt
#   inflating: MVSA_Single/data/3516.jpg
#   inflating: MVSA_Single/data/3516.txt
#   inflating: MVSA_Single/data/3517.jpg
#  extracting: MVSA_Single/data/3517.txt
#   inflating: MVSA_Single/data/352.jpg
#   inflating: MVSA_Single/data/352.txt
#   inflating: MVSA_Single/data/3520.jpg
#  extracting: MVSA_Single/data/3520.txt
#   inflating: MVSA_Single/data/3521.jpg
#   inflating: MVSA_Single/data/3521.txt
#   inflating: MVSA_Single/data/3522.jpg
#   inflating: MVSA_Single/data/3522.txt
#   inflating: MVSA_Single/data/3523.jpg
#   inflating: MVSA_Single/data/3523.txt
#   inflating: MVSA_Single/data/3524.jpg
#   inflating: MVSA_Single/data/3524.txt
#   inflating: MVSA_Single/data/3525.jpg
#   inflating: MVSA_Single/data/3525.txt
#   inflating: MVSA_Single/data/3526.jpg
#   inflating: MVSA_Single/data/3526.txt
#   inflating: MVSA_Single/data/3527.jpg
#   inflating: MVSA_Single/data/3527.txt
#   inflating: MVSA_Single/data/3528.jpg
#   inflating: MVSA_Single/data/3528.txt
#   inflating: MVSA_Single/data/3529.jpg
#  extracting: MVSA_Single/data/3529.txt
#   inflating: MVSA_Single/data/353.jpg
#   inflating: MVSA_Single/data/353.txt
#   inflating: MVSA_Single/data/3530.jpg
#   inflating: MVSA_Single/data/3530.txt
#   inflating: MVSA_Single/data/3531.jpg
#   inflating: MVSA_Single/data/3531.txt
#   inflating: MVSA_Single/data/3532.jpg
#  extracting: MVSA_Single/data/3532.txt
#   inflating: MVSA_Single/data/3533.jpg
#   inflating: MVSA_Single/data/3533.txt
#   inflating: MVSA_Single/data/3534.jpg
#   inflating: MVSA_Single/data/3534.txt
#   inflating: MVSA_Single/data/3535.jpg
#  extracting: MVSA_Single/data/3535.txt
#   inflating: MVSA_Single/data/3536.jpg
#  extracting: MVSA_Single/data/3536.txt
#   inflating: MVSA_Single/data/3537.jpg
#  extracting: MVSA_Single/data/3537.txt
#   inflating: MVSA_Single/data/3538.jpg
#  extracting: MVSA_Single/data/3538.txt
#   inflating: MVSA_Single/data/3539.jpg
#  extracting: MVSA_Single/data/3539.txt
#   inflating: MVSA_Single/data/354.jpg
#  extracting: MVSA_Single/data/354.txt
#   inflating: MVSA_Single/data/3540.jpg
#  extracting: MVSA_Single/data/3540.txt
#   inflating: MVSA_Single/data/3541.jpg
#  extracting: MVSA_Single/data/3541.txt
#   inflating: MVSA_Single/data/3542.jpg
#  extracting: MVSA_Single/data/3542.txt
#   inflating: MVSA_Single/data/3543.jpg
#   inflating: MVSA_Single/data/3543.txt
#   inflating: MVSA_Single/data/3544.jpg
#  extracting: MVSA_Single/data/3544.txt
#   inflating: MVSA_Single/data/3545.jpg
#  extracting: MVSA_Single/data/3545.txt
#   inflating: MVSA_Single/data/3546.jpg
#  extracting: MVSA_Single/data/3546.txt
#   inflating: MVSA_Single/data/3547.jpg
#   inflating: MVSA_Single/data/3547.txt
#   inflating: MVSA_Single/data/3548.jpg
#   inflating: MVSA_Single/data/3548.txt
#   inflating: MVSA_Single/data/3549.jpg
#   inflating: MVSA_Single/data/3549.txt
#   inflating: MVSA_Single/data/355.jpg
#  extracting: MVSA_Single/data/355.txt
#   inflating: MVSA_Single/data/3550.jpg
#   inflating: MVSA_Single/data/3550.txt
#   inflating: MVSA_Single/data/3551.jpg
#   inflating: MVSA_Single/data/3551.txt
#   inflating: MVSA_Single/data/3552.jpg
#   inflating: MVSA_Single/data/3552.txt
#   inflating: MVSA_Single/data/3553.jpg
#   inflating: MVSA_Single/data/3553.txt
#   inflating: MVSA_Single/data/3554.jpg
#   inflating: MVSA_Single/data/3554.txt
#   inflating: MVSA_Single/data/3555.jpg
#   inflating: MVSA_Single/data/3555.txt
#   inflating: MVSA_Single/data/3556.jpg
#   inflating: MVSA_Single/data/3556.txt
#   inflating: MVSA_Single/data/3557.jpg
#   inflating: MVSA_Single/data/3557.txt
#   inflating: MVSA_Single/data/3558.jpg
#  extracting: MVSA_Single/data/3558.txt
#   inflating: MVSA_Single/data/3559.jpg
#   inflating: MVSA_Single/data/3559.txt
#   inflating: MVSA_Single/data/356.jpg
#   inflating: MVSA_Single/data/356.txt
#   inflating: MVSA_Single/data/3560.jpg
#   inflating: MVSA_Single/data/3560.txt
#   inflating: MVSA_Single/data/3561.jpg
#   inflating: MVSA_Single/data/3561.txt
#   inflating: MVSA_Single/data/3562.jpg
#   inflating: MVSA_Single/data/3562.txt
#   inflating: MVSA_Single/data/3563.jpg
#  extracting: MVSA_Single/data/3563.txt
#   inflating: MVSA_Single/data/3564.jpg
#   inflating: MVSA_Single/data/3564.txt
#   inflating: MVSA_Single/data/3565.jpg
#  extracting: MVSA_Single/data/3565.txt
#   inflating: MVSA_Single/data/3566.jpg
#   inflating: MVSA_Single/data/3566.txt
#   inflating: MVSA_Single/data/3567.jpg
#  extracting: MVSA_Single/data/3567.txt
#   inflating: MVSA_Single/data/3568.jpg
#  extracting: MVSA_Single/data/3568.txt
#   inflating: MVSA_Single/data/3569.jpg
#  extracting: MVSA_Single/data/3569.txt
#   inflating: MVSA_Single/data/357.jpg
#  extracting: MVSA_Single/data/357.txt
#   inflating: MVSA_Single/data/3570.jpg
#   inflating: MVSA_Single/data/3570.txt
#   inflating: MVSA_Single/data/3571.jpg
#  extracting: MVSA_Single/data/3571.txt
#   inflating: MVSA_Single/data/3572.jpg
#   inflating: MVSA_Single/data/3572.txt
#   inflating: MVSA_Single/data/3573.jpg
#  extracting: MVSA_Single/data/3573.txt
#   inflating: MVSA_Single/data/3574.jpg
#  extracting: MVSA_Single/data/3574.txt
#   inflating: MVSA_Single/data/3575.jpg
#   inflating: MVSA_Single/data/3575.txt
#   inflating: MVSA_Single/data/3576.jpg
#   inflating: MVSA_Single/data/3576.txt
#   inflating: MVSA_Single/data/3577.jpg
#  extracting: MVSA_Single/data/3577.txt
#   inflating: MVSA_Single/data/3578.jpg
#   inflating: MVSA_Single/data/3578.txt
#   inflating: MVSA_Single/data/3579.jpg
#   inflating: MVSA_Single/data/3579.txt
#   inflating: MVSA_Single/data/358.jpg
#   inflating: MVSA_Single/data/358.txt
#   inflating: MVSA_Single/data/3580.jpg
#  extracting: MVSA_Single/data/3580.txt
#   inflating: MVSA_Single/data/3581.jpg
#   inflating: MVSA_Single/data/3581.txt
#   inflating: MVSA_Single/data/3582.jpg
#   inflating: MVSA_Single/data/3582.txt
#   inflating: MVSA_Single/data/3583.jpg
#   inflating: MVSA_Single/data/3583.txt
#   inflating: MVSA_Single/data/3584.jpg
#   inflating: MVSA_Single/data/3584.txt
#   inflating: MVSA_Single/data/3585.jpg
#  extracting: MVSA_Single/data/3585.txt
#   inflating: MVSA_Single/data/3586.jpg
#   inflating: MVSA_Single/data/3586.txt
#   inflating: MVSA_Single/data/3587.jpg
#   inflating: MVSA_Single/data/3587.txt
#   inflating: MVSA_Single/data/3588.jpg
#   inflating: MVSA_Single/data/3588.txt
#   inflating: MVSA_Single/data/3589.jpg
#   inflating: MVSA_Single/data/3589.txt
#   inflating: MVSA_Single/data/359.jpg
#  extracting: MVSA_Single/data/359.txt
#   inflating: MVSA_Single/data/3590.jpg
#   inflating: MVSA_Single/data/3590.txt
#   inflating: MVSA_Single/data/3591.jpg
#  extracting: MVSA_Single/data/3591.txt
#   inflating: MVSA_Single/data/3592.jpg
#   inflating: MVSA_Single/data/3592.txt
#   inflating: MVSA_Single/data/3593.jpg
#   inflating: MVSA_Single/data/3593.txt
#   inflating: MVSA_Single/data/3594.jpg
#  extracting: MVSA_Single/data/3594.txt
#   inflating: MVSA_Single/data/3595.jpg
#   inflating: MVSA_Single/data/3595.txt
#   inflating: MVSA_Single/data/3596.jpg
#   inflating: MVSA_Single/data/3596.txt
#   inflating: MVSA_Single/data/3597.jpg
#   inflating: MVSA_Single/data/3597.txt
#   inflating: MVSA_Single/data/3598.jpg
#  extracting: MVSA_Single/data/3598.txt
#   inflating: MVSA_Single/data/3599.jpg
#  extracting: MVSA_Single/data/3599.txt
#   inflating: MVSA_Single/data/36.jpg
#  extracting: MVSA_Single/data/36.txt
#   inflating: MVSA_Single/data/360.jpg
#   inflating: MVSA_Single/data/360.txt
#   inflating: MVSA_Single/data/3600.jpg
#   inflating: MVSA_Single/data/3600.txt
#   inflating: MVSA_Single/data/3601.jpg
#   inflating: MVSA_Single/data/3601.txt
#   inflating: MVSA_Single/data/3602.jpg
#  extracting: MVSA_Single/data/3602.txt
#   inflating: MVSA_Single/data/3603.jpg
#   inflating: MVSA_Single/data/3603.txt
#   inflating: MVSA_Single/data/3604.jpg
#  extracting: MVSA_Single/data/3604.txt
#   inflating: MVSA_Single/data/3605.jpg
#   inflating: MVSA_Single/data/3605.txt
#   inflating: MVSA_Single/data/3606.jpg
#  extracting: MVSA_Single/data/3606.txt
#   inflating: MVSA_Single/data/3607.jpg
#  extracting: MVSA_Single/data/3607.txt
#   inflating: MVSA_Single/data/3608.jpg
#  extracting: MVSA_Single/data/3608.txt
#   inflating: MVSA_Single/data/3609.jpg
#   inflating: MVSA_Single/data/3609.txt
#   inflating: MVSA_Single/data/361.jpg
#   inflating: MVSA_Single/data/361.txt
#   inflating: MVSA_Single/data/3610.jpg
#   inflating: MVSA_Single/data/3610.txt
#   inflating: MVSA_Single/data/3611.jpg
#   inflating: MVSA_Single/data/3611.txt
#   inflating: MVSA_Single/data/3612.jpg
#   inflating: MVSA_Single/data/3612.txt
#   inflating: MVSA_Single/data/3613.jpg
#   inflating: MVSA_Single/data/3613.txt
#   inflating: MVSA_Single/data/3614.jpg
#   inflating: MVSA_Single/data/3614.txt
#   inflating: MVSA_Single/data/3615.jpg
#   inflating: MVSA_Single/data/3615.txt
#   inflating: MVSA_Single/data/3616.jpg
#   inflating: MVSA_Single/data/3616.txt
#   inflating: MVSA_Single/data/3617.jpg
#   inflating: MVSA_Single/data/3617.txt
#   inflating: MVSA_Single/data/3618.jpg
#   inflating: MVSA_Single/data/3618.txt
#   inflating: MVSA_Single/data/3619.jpg
#  extracting: MVSA_Single/data/3619.txt
#   inflating: MVSA_Single/data/362.jpg
#   inflating: MVSA_Single/data/362.txt
#   inflating: MVSA_Single/data/3620.jpg
#  extracting: MVSA_Single/data/3620.txt
#   inflating: MVSA_Single/data/3621.jpg
#   inflating: MVSA_Single/data/3621.txt
#   inflating: MVSA_Single/data/3622.jpg
#   inflating: MVSA_Single/data/3622.txt
#   inflating: MVSA_Single/data/3623.jpg
#  extracting: MVSA_Single/data/3623.txt
#   inflating: MVSA_Single/data/3624.jpg
#   inflating: MVSA_Single/data/3624.txt
#   inflating: MVSA_Single/data/3625.jpg
#   inflating: MVSA_Single/data/3625.txt
#   inflating: MVSA_Single/data/3626.jpg
#   inflating: MVSA_Single/data/3626.txt
#   inflating: MVSA_Single/data/3627.jpg
#   inflating: MVSA_Single/data/3627.txt
#   inflating: MVSA_Single/data/3628.jpg
#   inflating: MVSA_Single/data/3628.txt
#   inflating: MVSA_Single/data/3629.jpg
#  extracting: MVSA_Single/data/3629.txt
#   inflating: MVSA_Single/data/363.jpg
#  extracting: MVSA_Single/data/363.txt
#   inflating: MVSA_Single/data/3630.jpg
#  extracting: MVSA_Single/data/3630.txt
#   inflating: MVSA_Single/data/3631.jpg
#  extracting: MVSA_Single/data/3631.txt
#   inflating: MVSA_Single/data/3632.jpg
#   inflating: MVSA_Single/data/3632.txt
#   inflating: MVSA_Single/data/3633.jpg
#   inflating: MVSA_Single/data/3633.txt
#   inflating: MVSA_Single/data/3634.jpg
#   inflating: MVSA_Single/data/3634.txt
#   inflating: MVSA_Single/data/3635.jpg
#   inflating: MVSA_Single/data/3635.txt
#   inflating: MVSA_Single/data/3636.jpg
#  extracting: MVSA_Single/data/3636.txt
#   inflating: MVSA_Single/data/3637.jpg
#   inflating: MVSA_Single/data/3637.txt
#   inflating: MVSA_Single/data/3638.jpg
#  extracting: MVSA_Single/data/3638.txt
#   inflating: MVSA_Single/data/3639.jpg
#   inflating: MVSA_Single/data/3639.txt
#   inflating: MVSA_Single/data/364.jpg
#  extracting: MVSA_Single/data/364.txt
#   inflating: MVSA_Single/data/3640.jpg
#   inflating: MVSA_Single/data/3640.txt
#   inflating: MVSA_Single/data/3641.jpg
#   inflating: MVSA_Single/data/3641.txt
#   inflating: MVSA_Single/data/3642.jpg
#   inflating: MVSA_Single/data/3642.txt
#   inflating: MVSA_Single/data/3643.jpg
#   inflating: MVSA_Single/data/3643.txt
#   inflating: MVSA_Single/data/3644.jpg
#   inflating: MVSA_Single/data/3644.txt
#   inflating: MVSA_Single/data/3645.jpg
#   inflating: MVSA_Single/data/3645.txt
#   inflating: MVSA_Single/data/3646.jpg
#   inflating: MVSA_Single/data/3646.txt
#   inflating: MVSA_Single/data/3647.jpg
#  extracting: MVSA_Single/data/3647.txt
#   inflating: MVSA_Single/data/3648.jpg
#  extracting: MVSA_Single/data/3648.txt
#   inflating: MVSA_Single/data/3649.jpg
#   inflating: MVSA_Single/data/3649.txt
#   inflating: MVSA_Single/data/365.jpg
#  extracting: MVSA_Single/data/365.txt
#   inflating: MVSA_Single/data/3650.jpg
#  extracting: MVSA_Single/data/3650.txt
#   inflating: MVSA_Single/data/3651.jpg
#   inflating: MVSA_Single/data/3651.txt
#   inflating: MVSA_Single/data/3652.jpg
#   inflating: MVSA_Single/data/3652.txt
#   inflating: MVSA_Single/data/3653.jpg
#   inflating: MVSA_Single/data/3653.txt
#   inflating: MVSA_Single/data/3654.jpg
#   inflating: MVSA_Single/data/3654.txt
#   inflating: MVSA_Single/data/3655.jpg
#   inflating: MVSA_Single/data/3655.txt
#   inflating: MVSA_Single/data/3656.jpg
#   inflating: MVSA_Single/data/3656.txt
#   inflating: MVSA_Single/data/3657.jpg
#   inflating: MVSA_Single/data/3657.txt
#   inflating: MVSA_Single/data/3658.jpg
#   inflating: MVSA_Single/data/3658.txt
#   inflating: MVSA_Single/data/3659.jpg
#  extracting: MVSA_Single/data/3659.txt
#   inflating: MVSA_Single/data/366.jpg
#   inflating: MVSA_Single/data/366.txt
#   inflating: MVSA_Single/data/3660.jpg
#  extracting: MVSA_Single/data/3660.txt
#   inflating: MVSA_Single/data/3661.jpg
#   inflating: MVSA_Single/data/3661.txt
#   inflating: MVSA_Single/data/3662.jpg
#   inflating: MVSA_Single/data/3662.txt
#   inflating: MVSA_Single/data/3663.jpg
#   inflating: MVSA_Single/data/3663.txt
#   inflating: MVSA_Single/data/3664.jpg
#  extracting: MVSA_Single/data/3664.txt
#   inflating: MVSA_Single/data/3665.jpg
#  extracting: MVSA_Single/data/3665.txt
#   inflating: MVSA_Single/data/3666.jpg
#   inflating: MVSA_Single/data/3666.txt
#   inflating: MVSA_Single/data/3667.jpg
#  extracting: MVSA_Single/data/3667.txt
#   inflating: MVSA_Single/data/3668.jpg
#  extracting: MVSA_Single/data/3668.txt
#   inflating: MVSA_Single/data/3669.jpg
#  extracting: MVSA_Single/data/3669.txt
#   inflating: MVSA_Single/data/367.jpg
#  extracting: MVSA_Single/data/367.txt
#   inflating: MVSA_Single/data/3670.jpg
#   inflating: MVSA_Single/data/3670.txt
#   inflating: MVSA_Single/data/3671.jpg
#   inflating: MVSA_Single/data/3671.txt
#   inflating: MVSA_Single/data/3672.jpg
#   inflating: MVSA_Single/data/3672.txt
#   inflating: MVSA_Single/data/3673.jpg
#   inflating: MVSA_Single/data/3673.txt
#   inflating: MVSA_Single/data/3674.jpg
#   inflating: MVSA_Single/data/3674.txt
#   inflating: MVSA_Single/data/3675.jpg
#  extracting: MVSA_Single/data/3675.txt
#   inflating: MVSA_Single/data/3676.jpg
#  extracting: MVSA_Single/data/3676.txt
#   inflating: MVSA_Single/data/3677.jpg
#  extracting: MVSA_Single/data/3677.txt
#   inflating: MVSA_Single/data/3678.jpg
#   inflating: MVSA_Single/data/3678.txt
#   inflating: MVSA_Single/data/3679.jpg
#   inflating: MVSA_Single/data/3679.txt
#   inflating: MVSA_Single/data/368.jpg
#  extracting: MVSA_Single/data/368.txt
#   inflating: MVSA_Single/data/3680.jpg
#  extracting: MVSA_Single/data/3680.txt
#   inflating: MVSA_Single/data/3681.jpg
#   inflating: MVSA_Single/data/3681.txt
#   inflating: MVSA_Single/data/3682.jpg
#   inflating: MVSA_Single/data/3682.txt
#   inflating: MVSA_Single/data/3684.jpg
#   inflating: MVSA_Single/data/3684.txt
#   inflating: MVSA_Single/data/3685.jpg
#   inflating: MVSA_Single/data/3685.txt
#   inflating: MVSA_Single/data/3686.jpg
#  extracting: MVSA_Single/data/3686.txt
#   inflating: MVSA_Single/data/3687.jpg
#   inflating: MVSA_Single/data/3687.txt
#   inflating: MVSA_Single/data/3688.jpg
#  extracting: MVSA_Single/data/3688.txt
#   inflating: MVSA_Single/data/3689.jpg
#  extracting: MVSA_Single/data/3689.txt
#   inflating: MVSA_Single/data/369.jpg
#   inflating: MVSA_Single/data/369.txt
#   inflating: MVSA_Single/data/3690.jpg
#  extracting: MVSA_Single/data/3690.txt
#   inflating: MVSA_Single/data/3691.jpg
#  extracting: MVSA_Single/data/3691.txt
#   inflating: MVSA_Single/data/3692.jpg
#   inflating: MVSA_Single/data/3692.txt
#   inflating: MVSA_Single/data/3693.jpg
#   inflating: MVSA_Single/data/3693.txt
#   inflating: MVSA_Single/data/3694.jpg
#   inflating: MVSA_Single/data/3694.txt
#   inflating: MVSA_Single/data/3695.jpg
#   inflating: MVSA_Single/data/3695.txt
#   inflating: MVSA_Single/data/3696.jpg
#  extracting: MVSA_Single/data/3696.txt
#   inflating: MVSA_Single/data/3697.jpg
#   inflating: MVSA_Single/data/3697.txt
#   inflating: MVSA_Single/data/3698.jpg
#   inflating: MVSA_Single/data/3698.txt
#   inflating: MVSA_Single/data/3699.jpg
#   inflating: MVSA_Single/data/3699.txt
#   inflating: MVSA_Single/data/37.jpg
#  extracting: MVSA_Single/data/37.txt
#   inflating: MVSA_Single/data/370.jpg
#   inflating: MVSA_Single/data/370.txt
#   inflating: MVSA_Single/data/3700.jpg
#  extracting: MVSA_Single/data/3700.txt
#   inflating: MVSA_Single/data/3701.jpg
#   inflating: MVSA_Single/data/3701.txt
#   inflating: MVSA_Single/data/3703.jpg
#   inflating: MVSA_Single/data/3703.txt
#   inflating: MVSA_Single/data/3704.jpg
#   inflating: MVSA_Single/data/3704.txt
#   inflating: MVSA_Single/data/3705.jpg
#   inflating: MVSA_Single/data/3705.txt
#   inflating: MVSA_Single/data/3706.jpg
#   inflating: MVSA_Single/data/3706.txt
#   inflating: MVSA_Single/data/3708.jpg
#  extracting: MVSA_Single/data/3708.txt
#   inflating: MVSA_Single/data/3709.jpg
#   inflating: MVSA_Single/data/3709.txt
#   inflating: MVSA_Single/data/371.jpg
#   inflating: MVSA_Single/data/371.txt
#   inflating: MVSA_Single/data/3710.jpg
#   inflating: MVSA_Single/data/3710.txt
#   inflating: MVSA_Single/data/3711.jpg
#   inflating: MVSA_Single/data/3711.txt
#   inflating: MVSA_Single/data/3712.jpg
#   inflating: MVSA_Single/data/3712.txt
#   inflating: MVSA_Single/data/3713.jpg
#  extracting: MVSA_Single/data/3713.txt
#   inflating: MVSA_Single/data/3714.jpg
#  extracting: MVSA_Single/data/3714.txt
#   inflating: MVSA_Single/data/3715.jpg
#  extracting: MVSA_Single/data/3715.txt
#   inflating: MVSA_Single/data/3716.jpg
#  extracting: MVSA_Single/data/3716.txt
#   inflating: MVSA_Single/data/3717.jpg
#  extracting: MVSA_Single/data/3717.txt
#   inflating: MVSA_Single/data/3718.jpg
#   inflating: MVSA_Single/data/3718.txt
#   inflating: MVSA_Single/data/3719.jpg
#   inflating: MVSA_Single/data/3719.txt
#   inflating: MVSA_Single/data/372.jpg
#  extracting: MVSA_Single/data/372.txt
#   inflating: MVSA_Single/data/3720.jpg
#   inflating: MVSA_Single/data/3720.txt
#   inflating: MVSA_Single/data/3721.jpg
#   inflating: MVSA_Single/data/3721.txt
#   inflating: MVSA_Single/data/3722.jpg
#   inflating: MVSA_Single/data/3722.txt
#   inflating: MVSA_Single/data/3723.jpg
#  extracting: MVSA_Single/data/3723.txt
#   inflating: MVSA_Single/data/3724.jpg
#   inflating: MVSA_Single/data/3724.txt
#   inflating: MVSA_Single/data/3725.jpg
#  extracting: MVSA_Single/data/3725.txt
#   inflating: MVSA_Single/data/3726.jpg
#  extracting: MVSA_Single/data/3726.txt
#   inflating: MVSA_Single/data/3727.jpg
#  extracting: MVSA_Single/data/3727.txt
#   inflating: MVSA_Single/data/3728.jpg
#   inflating: MVSA_Single/data/3728.txt
#   inflating: MVSA_Single/data/3729.jpg
#   inflating: MVSA_Single/data/3729.txt
#   inflating: MVSA_Single/data/373.jpg
#  extracting: MVSA_Single/data/373.txt
#   inflating: MVSA_Single/data/3730.jpg
#   inflating: MVSA_Single/data/3730.txt
#   inflating: MVSA_Single/data/3731.jpg
#   inflating: MVSA_Single/data/3731.txt
#   inflating: MVSA_Single/data/3732.jpg
#   inflating: MVSA_Single/data/3732.txt
#   inflating: MVSA_Single/data/3733.jpg
#  extracting: MVSA_Single/data/3733.txt
#   inflating: MVSA_Single/data/3734.jpg
#   inflating: MVSA_Single/data/3734.txt
#   inflating: MVSA_Single/data/3735.jpg
#   inflating: MVSA_Single/data/3735.txt
#   inflating: MVSA_Single/data/3736.jpg
#   inflating: MVSA_Single/data/3736.txt
#   inflating: MVSA_Single/data/3737.jpg
#   inflating: MVSA_Single/data/3737.txt
#   inflating: MVSA_Single/data/3738.jpg
#   inflating: MVSA_Single/data/3738.txt
#   inflating: MVSA_Single/data/374.jpg
#   inflating: MVSA_Single/data/374.txt
#   inflating: MVSA_Single/data/3740.jpg
#   inflating: MVSA_Single/data/3740.txt
#   inflating: MVSA_Single/data/3741.jpg
#   inflating: MVSA_Single/data/3741.txt
#   inflating: MVSA_Single/data/3742.jpg
#   inflating: MVSA_Single/data/3742.txt
#   inflating: MVSA_Single/data/3743.jpg
#   inflating: MVSA_Single/data/3743.txt
#   inflating: MVSA_Single/data/3744.jpg
#   inflating: MVSA_Single/data/3744.txt
#   inflating: MVSA_Single/data/3745.jpg
#   inflating: MVSA_Single/data/3745.txt
#   inflating: MVSA_Single/data/3747.jpg
#   inflating: MVSA_Single/data/3747.txt
#   inflating: MVSA_Single/data/3748.jpg
#   inflating: MVSA_Single/data/3748.txt
#   inflating: MVSA_Single/data/3749.jpg
#   inflating: MVSA_Single/data/3749.txt
#   inflating: MVSA_Single/data/375.jpg
#  extracting: MVSA_Single/data/375.txt
#   inflating: MVSA_Single/data/3750.jpg
#   inflating: MVSA_Single/data/3750.txt
#   inflating: MVSA_Single/data/3752.jpg
#   inflating: MVSA_Single/data/3752.txt
#   inflating: MVSA_Single/data/3753.jpg
#   inflating: MVSA_Single/data/3753.txt
#   inflating: MVSA_Single/data/3754.jpg
#  extracting: MVSA_Single/data/3754.txt
#   inflating: MVSA_Single/data/3755.jpg
#  extracting: MVSA_Single/data/3755.txt
#   inflating: MVSA_Single/data/3756.jpg
#   inflating: MVSA_Single/data/3756.txt
#   inflating: MVSA_Single/data/3758.jpg
#   inflating: MVSA_Single/data/3758.txt
#   inflating: MVSA_Single/data/3759.jpg
#   inflating: MVSA_Single/data/3759.txt
#   inflating: MVSA_Single/data/376.jpg
#   inflating: MVSA_Single/data/376.txt
#   inflating: MVSA_Single/data/3760.jpg
#   inflating: MVSA_Single/data/3760.txt
#   inflating: MVSA_Single/data/3761.jpg
#   inflating: MVSA_Single/data/3761.txt
#   inflating: MVSA_Single/data/3762.jpg
#  extracting: MVSA_Single/data/3762.txt
#   inflating: MVSA_Single/data/3763.jpg
#   inflating: MVSA_Single/data/3763.txt
#   inflating: MVSA_Single/data/3764.jpg
#   inflating: MVSA_Single/data/3764.txt
#   inflating: MVSA_Single/data/3765.jpg
#  extracting: MVSA_Single/data/3765.txt
#   inflating: MVSA_Single/data/3766.jpg
#   inflating: MVSA_Single/data/3766.txt
#   inflating: MVSA_Single/data/3767.jpg
#   inflating: MVSA_Single/data/3767.txt
#   inflating: MVSA_Single/data/3768.jpg
#   inflating: MVSA_Single/data/3768.txt
#   inflating: MVSA_Single/data/3769.jpg
#  extracting: MVSA_Single/data/3769.txt
#   inflating: MVSA_Single/data/377.jpg
#  extracting: MVSA_Single/data/377.txt
#   inflating: MVSA_Single/data/3770.jpg
#   inflating: MVSA_Single/data/3770.txt
#   inflating: MVSA_Single/data/3771.jpg
#   inflating: MVSA_Single/data/3771.txt
#   inflating: MVSA_Single/data/3772.jpg
#   inflating: MVSA_Single/data/3772.txt
#   inflating: MVSA_Single/data/3773.jpg
#   inflating: MVSA_Single/data/3773.txt
#   inflating: MVSA_Single/data/3774.jpg
#   inflating: MVSA_Single/data/3774.txt
#   inflating: MVSA_Single/data/3775.jpg
#   inflating: MVSA_Single/data/3775.txt
#   inflating: MVSA_Single/data/3776.jpg
#   inflating: MVSA_Single/data/3776.txt
#   inflating: MVSA_Single/data/3777.jpg
#   inflating: MVSA_Single/data/3777.txt
#   inflating: MVSA_Single/data/3778.jpg
#   inflating: MVSA_Single/data/3778.txt
#   inflating: MVSA_Single/data/3779.jpg
#   inflating: MVSA_Single/data/3779.txt
#   inflating: MVSA_Single/data/378.jpg
#   inflating: MVSA_Single/data/378.txt
#   inflating: MVSA_Single/data/3780.jpg
#   inflating: MVSA_Single/data/3780.txt
#   inflating: MVSA_Single/data/3781.jpg
#   inflating: MVSA_Single/data/3781.txt
#   inflating: MVSA_Single/data/3782.jpg
#   inflating: MVSA_Single/data/3782.txt
#   inflating: MVSA_Single/data/3783.jpg
#   inflating: MVSA_Single/data/3783.txt
#   inflating: MVSA_Single/data/3784.jpg
#   inflating: MVSA_Single/data/3784.txt
#   inflating: MVSA_Single/data/3785.jpg
#   inflating: MVSA_Single/data/3785.txt
#   inflating: MVSA_Single/data/3786.jpg
#   inflating: MVSA_Single/data/3786.txt
#   inflating: MVSA_Single/data/3787.jpg
#   inflating: MVSA_Single/data/3787.txt
#   inflating: MVSA_Single/data/3788.jpg
#  extracting: MVSA_Single/data/3788.txt
#   inflating: MVSA_Single/data/3789.jpg
#  extracting: MVSA_Single/data/3789.txt
#   inflating: MVSA_Single/data/379.jpg
#  extracting: MVSA_Single/data/379.txt
#   inflating: MVSA_Single/data/3790.jpg
#  extracting: MVSA_Single/data/3790.txt
#   inflating: MVSA_Single/data/3791.jpg
#  extracting: MVSA_Single/data/3791.txt
#   inflating: MVSA_Single/data/3792.jpg
#   inflating: MVSA_Single/data/3792.txt
#   inflating: MVSA_Single/data/3793.jpg
#   inflating: MVSA_Single/data/3793.txt
#   inflating: MVSA_Single/data/3794.jpg
#  extracting: MVSA_Single/data/3794.txt
#   inflating: MVSA_Single/data/3795.jpg
#   inflating: MVSA_Single/data/3795.txt
#   inflating: MVSA_Single/data/3796.jpg
#  extracting: MVSA_Single/data/3796.txt
#   inflating: MVSA_Single/data/3797.jpg
#   inflating: MVSA_Single/data/3797.txt
#   inflating: MVSA_Single/data/3798.jpg
#  extracting: MVSA_Single/data/3798.txt
#   inflating: MVSA_Single/data/3799.jpg
#   inflating: MVSA_Single/data/3799.txt
#   inflating: MVSA_Single/data/38.jpg
#  extracting: MVSA_Single/data/38.txt
#   inflating: MVSA_Single/data/380.jpg
#  extracting: MVSA_Single/data/380.txt
#   inflating: MVSA_Single/data/3800.jpg
#   inflating: MVSA_Single/data/3800.txt
#   inflating: MVSA_Single/data/3801.jpg
#   inflating: MVSA_Single/data/3801.txt
#   inflating: MVSA_Single/data/3802.jpg
#  extracting: MVSA_Single/data/3802.txt
#   inflating: MVSA_Single/data/3805.jpg
#   inflating: MVSA_Single/data/3805.txt
#   inflating: MVSA_Single/data/3806.jpg
#   inflating: MVSA_Single/data/3806.txt
#   inflating: MVSA_Single/data/3807.jpg
#   inflating: MVSA_Single/data/3807.txt
#   inflating: MVSA_Single/data/3808.jpg
#   inflating: MVSA_Single/data/3808.txt
#   inflating: MVSA_Single/data/3809.jpg
#   inflating: MVSA_Single/data/3809.txt
#   inflating: MVSA_Single/data/381.jpg
#  extracting: MVSA_Single/data/381.txt
#   inflating: MVSA_Single/data/3811.jpg
#  extracting: MVSA_Single/data/3811.txt
#   inflating: MVSA_Single/data/3812.jpg
#  extracting: MVSA_Single/data/3812.txt
#   inflating: MVSA_Single/data/3813.jpg
#  extracting: MVSA_Single/data/3813.txt
#   inflating: MVSA_Single/data/3814.jpg
#   inflating: MVSA_Single/data/3814.txt
#   inflating: MVSA_Single/data/3815.jpg
#   inflating: MVSA_Single/data/3815.txt
#   inflating: MVSA_Single/data/3816.jpg
#   inflating: MVSA_Single/data/3816.txt
#   inflating: MVSA_Single/data/3817.jpg
#  extracting: MVSA_Single/data/3817.txt
#   inflating: MVSA_Single/data/3818.jpg
#  extracting: MVSA_Single/data/3818.txt
#   inflating: MVSA_Single/data/3819.jpg
#  extracting: MVSA_Single/data/3819.txt
#   inflating: MVSA_Single/data/382.jpg
#   inflating: MVSA_Single/data/382.txt
#   inflating: MVSA_Single/data/3820.jpg
#   inflating: MVSA_Single/data/3820.txt
#   inflating: MVSA_Single/data/3821.jpg
#   inflating: MVSA_Single/data/3821.txt
#   inflating: MVSA_Single/data/3822.jpg
#   inflating: MVSA_Single/data/3822.txt
#   inflating: MVSA_Single/data/3823.jpg
#  extracting: MVSA_Single/data/3823.txt
#   inflating: MVSA_Single/data/3824.jpg
#   inflating: MVSA_Single/data/3824.txt
#   inflating: MVSA_Single/data/3825.jpg
#  extracting: MVSA_Single/data/3825.txt
#   inflating: MVSA_Single/data/3826.jpg
#   inflating: MVSA_Single/data/3826.txt
#   inflating: MVSA_Single/data/3827.jpg
#   inflating: MVSA_Single/data/3827.txt
#   inflating: MVSA_Single/data/3828.jpg
#   inflating: MVSA_Single/data/3828.txt
#   inflating: MVSA_Single/data/3829.jpg
#   inflating: MVSA_Single/data/3829.txt
#   inflating: MVSA_Single/data/383.jpg
#  extracting: MVSA_Single/data/383.txt
#   inflating: MVSA_Single/data/3830.jpg
#  extracting: MVSA_Single/data/3830.txt
#   inflating: MVSA_Single/data/3831.jpg
#  extracting: MVSA_Single/data/3831.txt
#   inflating: MVSA_Single/data/3832.jpg
#   inflating: MVSA_Single/data/3832.txt
#   inflating: MVSA_Single/data/3833.jpg
#  extracting: MVSA_Single/data/3833.txt
#   inflating: MVSA_Single/data/3834.jpg
#   inflating: MVSA_Single/data/3834.txt
#   inflating: MVSA_Single/data/3835.jpg
#   inflating: MVSA_Single/data/3835.txt
#   inflating: MVSA_Single/data/3836.jpg
#  extracting: MVSA_Single/data/3836.txt
#   inflating: MVSA_Single/data/3837.jpg
#   inflating: MVSA_Single/data/3837.txt
#   inflating: MVSA_Single/data/3838.jpg
#  extracting: MVSA_Single/data/3838.txt
#   inflating: MVSA_Single/data/3839.jpg
#   inflating: MVSA_Single/data/3839.txt
#   inflating: MVSA_Single/data/384.jpg
#   inflating: MVSA_Single/data/384.txt
#   inflating: MVSA_Single/data/3840.jpg
#  extracting: MVSA_Single/data/3840.txt
#   inflating: MVSA_Single/data/3841.jpg
#  extracting: MVSA_Single/data/3841.txt
#   inflating: MVSA_Single/data/3842.jpg
#   inflating: MVSA_Single/data/3842.txt
#   inflating: MVSA_Single/data/3843.jpg
#  extracting: MVSA_Single/data/3843.txt
#   inflating: MVSA_Single/data/3844.jpg
#  extracting: MVSA_Single/data/3844.txt
#   inflating: MVSA_Single/data/3845.jpg
#   inflating: MVSA_Single/data/3845.txt
#   inflating: MVSA_Single/data/3846.jpg
#   inflating: MVSA_Single/data/3846.txt
#   inflating: MVSA_Single/data/3848.jpg
#   inflating: MVSA_Single/data/3848.txt
#   inflating: MVSA_Single/data/3849.jpg
#  extracting: MVSA_Single/data/3849.txt
#   inflating: MVSA_Single/data/385.jpg
#   inflating: MVSA_Single/data/385.txt
#   inflating: MVSA_Single/data/3850.jpg
#   inflating: MVSA_Single/data/3850.txt
#   inflating: MVSA_Single/data/3851.jpg
#  extracting: MVSA_Single/data/3851.txt
#   inflating: MVSA_Single/data/3852.jpg
#   inflating: MVSA_Single/data/3852.txt
#   inflating: MVSA_Single/data/3853.jpg
#  extracting: MVSA_Single/data/3853.txt
#   inflating: MVSA_Single/data/3854.jpg
#   inflating: MVSA_Single/data/3854.txt
#   inflating: MVSA_Single/data/3855.jpg
#   inflating: MVSA_Single/data/3855.txt
#   inflating: MVSA_Single/data/3856.jpg
#   inflating: MVSA_Single/data/3856.txt
#   inflating: MVSA_Single/data/3857.jpg
#   inflating: MVSA_Single/data/3857.txt
#   inflating: MVSA_Single/data/3858.jpg
#  extracting: MVSA_Single/data/3858.txt
#   inflating: MVSA_Single/data/3859.jpg
#   inflating: MVSA_Single/data/3859.txt
#   inflating: MVSA_Single/data/386.jpg
#   inflating: MVSA_Single/data/386.txt
#   inflating: MVSA_Single/data/3860.jpg
#   inflating: MVSA_Single/data/3860.txt
#   inflating: MVSA_Single/data/3861.jpg
#   inflating: MVSA_Single/data/3861.txt
#   inflating: MVSA_Single/data/3862.jpg
#   inflating: MVSA_Single/data/3862.txt
#   inflating: MVSA_Single/data/3863.jpg
#  extracting: MVSA_Single/data/3863.txt
#   inflating: MVSA_Single/data/3864.jpg
#   inflating: MVSA_Single/data/3864.txt
#   inflating: MVSA_Single/data/3865.jpg
#   inflating: MVSA_Single/data/3865.txt
#   inflating: MVSA_Single/data/3866.jpg
#   inflating: MVSA_Single/data/3866.txt
#   inflating: MVSA_Single/data/3867.jpg
#  extracting: MVSA_Single/data/3867.txt
#   inflating: MVSA_Single/data/3868.jpg
#  extracting: MVSA_Single/data/3868.txt
#   inflating: MVSA_Single/data/3869.jpg
#  extracting: MVSA_Single/data/3869.txt
#   inflating: MVSA_Single/data/387.jpg
#   inflating: MVSA_Single/data/387.txt
#   inflating: MVSA_Single/data/3870.jpg
#  extracting: MVSA_Single/data/3870.txt
#   inflating: MVSA_Single/data/3871.jpg
#   inflating: MVSA_Single/data/3871.txt
#   inflating: MVSA_Single/data/3872.jpg
#   inflating: MVSA_Single/data/3872.txt
#   inflating: MVSA_Single/data/3873.jpg
#   inflating: MVSA_Single/data/3873.txt
#   inflating: MVSA_Single/data/3874.jpg
#  extracting: MVSA_Single/data/3874.txt
#   inflating: MVSA_Single/data/3875.jpg
#   inflating: MVSA_Single/data/3875.txt
#   inflating: MVSA_Single/data/3876.jpg
#   inflating: MVSA_Single/data/3876.txt
#   inflating: MVSA_Single/data/3877.jpg
#   inflating: MVSA_Single/data/3877.txt
#   inflating: MVSA_Single/data/3878.jpg
#   inflating: MVSA_Single/data/3878.txt
#   inflating: MVSA_Single/data/3879.jpg
#   inflating: MVSA_Single/data/3879.txt
#   inflating: MVSA_Single/data/388.jpg
#  extracting: MVSA_Single/data/388.txt
#   inflating: MVSA_Single/data/3880.jpg
#  extracting: MVSA_Single/data/3880.txt
#   inflating: MVSA_Single/data/3881.jpg
#  extracting: MVSA_Single/data/3881.txt
#   inflating: MVSA_Single/data/3882.jpg
#   inflating: MVSA_Single/data/3882.txt
#   inflating: MVSA_Single/data/3883.jpg
#   inflating: MVSA_Single/data/3883.txt
#   inflating: MVSA_Single/data/3884.jpg
#   inflating: MVSA_Single/data/3884.txt
#   inflating: MVSA_Single/data/3885.jpg
#  extracting: MVSA_Single/data/3885.txt
#   inflating: MVSA_Single/data/3886.jpg
#  extracting: MVSA_Single/data/3886.txt
#   inflating: MVSA_Single/data/3887.jpg
#  extracting: MVSA_Single/data/3887.txt
#   inflating: MVSA_Single/data/3888.jpg
#   inflating: MVSA_Single/data/3888.txt
#   inflating: MVSA_Single/data/3889.jpg
#   inflating: MVSA_Single/data/3889.txt
#   inflating: MVSA_Single/data/389.jpg
# ...
#  extracting: MVSA_Single/data/819.txt
#   inflating: MVSA_Single/data/82.jpg
#  extracting: MVSA_Single/data/82.txt
#   inflating: MVSA_Single/data/820.jpg
#   inflating: MVSA_Single/data/820.txt
#   inflating: MVSA_Single/data/821.jpg
#  extracting: MVSA_Single/data/821.txt
#   inflating: MVSA_Single/data/822.jpg
#   inflating: MVSA_Single/data/822.txt
#   inflating: MVSA_Single/data/823.jpg
#  extracting: MVSA_Single/data/823.txt
#   inflating: MVSA_Single/data/824.jpg
#   inflating: MVSA_Single/data/824.txt
#   inflating: MVSA_Single/data/825.jpg
#   inflating: MVSA_Single/data/825.txt
#   inflating: MVSA_Single/data/826.jpg
#  extracting: MVSA_Single/data/826.txt
#   inflating: MVSA_Single/data/827.jpg
#   inflating: MVSA_Single/data/827.txt
#   inflating: MVSA_Single/data/828.jpg
#  extracting: MVSA_Single/data/828.txt
#   inflating: MVSA_Single/data/829.jpg
#   inflating: MVSA_Single/data/829.txt
#   inflating: MVSA_Single/data/83.jpg
#  extracting: MVSA_Single/data/83.txt
#   inflating: MVSA_Single/data/830.jpg
#   inflating: MVSA_Single/data/830.txt
#   inflating: MVSA_Single/data/831.jpg
#   inflating: MVSA_Single/data/831.txt
#   inflating: MVSA_Single/data/832.jpg
#  extracting: MVSA_Single/data/832.txt
#   inflating: MVSA_Single/data/833.jpg
#   inflating: MVSA_Single/data/833.txt
#   inflating: MVSA_Single/data/834.jpg
#   inflating: MVSA_Single/data/834.txt
#   inflating: MVSA_Single/data/835.jpg
#   inflating: MVSA_Single/data/835.txt
#   inflating: MVSA_Single/data/836.jpg
#   inflating: MVSA_Single/data/836.txt
#   inflating: MVSA_Single/data/837.jpg
#   inflating: MVSA_Single/data/837.txt
#   inflating: MVSA_Single/data/838.jpg
#  extracting: MVSA_Single/data/838.txt
#   inflating: MVSA_Single/data/839.jpg
#   inflating: MVSA_Single/data/839.txt
#   inflating: MVSA_Single/data/84.jpg
#   inflating: MVSA_Single/data/84.txt
#   inflating: MVSA_Single/data/840.jpg
#  extracting: MVSA_Single/data/840.txt
#   inflating: MVSA_Single/data/841.jpg
#  extracting: MVSA_Single/data/841.txt
#   inflating: MVSA_Single/data/842.jpg
#   inflating: MVSA_Single/data/842.txt
#   inflating: MVSA_Single/data/843.jpg
#   inflating: MVSA_Single/data/843.txt
#   inflating: MVSA_Single/data/844.jpg
#   inflating: MVSA_Single/data/844.txt
#   inflating: MVSA_Single/data/845.jpg
#   inflating: MVSA_Single/data/845.txt
#   inflating: MVSA_Single/data/846.jpg
#  extracting: MVSA_Single/data/846.txt
#   inflating: MVSA_Single/data/847.jpg
#   inflating: MVSA_Single/data/847.txt
#   inflating: MVSA_Single/data/848.jpg
#   inflating: MVSA_Single/data/848.txt
#   inflating: MVSA_Single/data/849.jpg
#   inflating: MVSA_Single/data/849.txt
#   inflating: MVSA_Single/data/85.jpg
#   inflating: MVSA_Single/data/85.txt
#   inflating: MVSA_Single/data/850.jpg
#  extracting: MVSA_Single/data/850.txt
#   inflating: MVSA_Single/data/851.jpg
#  extracting: MVSA_Single/data/851.txt
#   inflating: MVSA_Single/data/852.jpg
#   inflating: MVSA_Single/data/852.txt
#   inflating: MVSA_Single/data/853.jpg
#  extracting: MVSA_Single/data/853.txt
#   inflating: MVSA_Single/data/854.jpg
#   inflating: MVSA_Single/data/854.txt
#   inflating: MVSA_Single/data/855.jpg
#   inflating: MVSA_Single/data/855.txt
#   inflating: MVSA_Single/data/856.jpg
#   inflating: MVSA_Single/data/856.txt
#   inflating: MVSA_Single/data/857.jpg
#  extracting: MVSA_Single/data/857.txt
#   inflating: MVSA_Single/data/858.jpg
#   inflating: MVSA_Single/data/858.txt
#   inflating: MVSA_Single/data/859.jpg
#   inflating: MVSA_Single/data/859.txt
#   inflating: MVSA_Single/data/86.jpg
#   inflating: MVSA_Single/data/86.txt
#   inflating: MVSA_Single/data/860.jpg
#   inflating: MVSA_Single/data/860.txt
#   inflating: MVSA_Single/data/861.jpg
#   inflating: MVSA_Single/data/861.txt
#   inflating: MVSA_Single/data/862.jpg
#   inflating: MVSA_Single/data/862.txt
#   inflating: MVSA_Single/data/863.jpg
#   inflating: MVSA_Single/data/863.txt
#   inflating: MVSA_Single/data/864.jpg
#   inflating: MVSA_Single/data/864.txt
#   inflating: MVSA_Single/data/865.jpg
#   inflating: MVSA_Single/data/865.txt
#   inflating: MVSA_Single/data/866.jpg
#  extracting: MVSA_Single/data/866.txt
#   inflating: MVSA_Single/data/867.jpg
#   inflating: MVSA_Single/data/867.txt
#   inflating: MVSA_Single/data/868.jpg
#   inflating: MVSA_Single/data/868.txt
#   inflating: MVSA_Single/data/869.jpg
#  extracting: MVSA_Single/data/869.txt
#   inflating: MVSA_Single/data/87.jpg
#   inflating: MVSA_Single/data/87.txt
#   inflating: MVSA_Single/data/870.jpg
#   inflating: MVSA_Single/data/870.txt
#   inflating: MVSA_Single/data/871.jpg
#  extracting: MVSA_Single/data/871.txt
#   inflating: MVSA_Single/data/872.jpg
#   inflating: MVSA_Single/data/872.txt
#   inflating: MVSA_Single/data/873.jpg
#   inflating: MVSA_Single/data/873.txt
#   inflating: MVSA_Single/data/874.jpg
#  extracting: MVSA_Single/data/874.txt
#   inflating: MVSA_Single/data/875.jpg
#   inflating: MVSA_Single/data/875.txt
#   inflating: MVSA_Single/data/876.jpg
#   inflating: MVSA_Single/data/876.txt
#   inflating: MVSA_Single/data/877.jpg
#   inflating: MVSA_Single/data/877.txt
#   inflating: MVSA_Single/data/878.jpg
#   inflating: MVSA_Single/data/878.txt
#   inflating: MVSA_Single/data/879.jpg
#   inflating: MVSA_Single/data/879.txt
#   inflating: MVSA_Single/data/88.jpg
#   inflating: MVSA_Single/data/88.txt
#   inflating: MVSA_Single/data/880.jpg
#   inflating: MVSA_Single/data/880.txt
#   inflating: MVSA_Single/data/881.jpg
#  extracting: MVSA_Single/data/881.txt
#   inflating: MVSA_Single/data/882.jpg
#  extracting: MVSA_Single/data/882.txt
#   inflating: MVSA_Single/data/883.jpg
#  extracting: MVSA_Single/data/883.txt
#   inflating: MVSA_Single/data/884.jpg
#   inflating: MVSA_Single/data/884.txt
#   inflating: MVSA_Single/data/885.jpg
#  extracting: MVSA_Single/data/885.txt
#   inflating: MVSA_Single/data/886.jpg
#   inflating: MVSA_Single/data/886.txt
#   inflating: MVSA_Single/data/887.jpg
#   inflating: MVSA_Single/data/887.txt
#   inflating: MVSA_Single/data/888.jpg
#   inflating: MVSA_Single/data/888.txt
#   inflating: MVSA_Single/data/889.jpg
#   inflating: MVSA_Single/data/889.txt
#   inflating: MVSA_Single/data/89.jpg
#   inflating: MVSA_Single/data/89.txt
#   inflating: MVSA_Single/data/890.jpg
#   inflating: MVSA_Single/data/890.txt
#   inflating: MVSA_Single/data/891.jpg
#  extracting: MVSA_Single/data/891.txt
#   inflating: MVSA_Single/data/892.jpg
#  extracting: MVSA_Single/data/892.txt
#   inflating: MVSA_Single/data/893.jpg
#   inflating: MVSA_Single/data/893.txt
#   inflating: MVSA_Single/data/894.jpg
#  extracting: MVSA_Single/data/894.txt
#   inflating: MVSA_Single/data/895.jpg
#  extracting: MVSA_Single/data/895.txt
#   inflating: MVSA_Single/data/896.jpg
#  extracting: MVSA_Single/data/896.txt
#   inflating: MVSA_Single/data/897.jpg
#   inflating: MVSA_Single/data/897.txt
#   inflating: MVSA_Single/data/898.jpg
#   inflating: MVSA_Single/data/898.txt
#   inflating: MVSA_Single/data/899.jpg
#   inflating: MVSA_Single/data/899.txt
#   inflating: MVSA_Single/data/9.jpg
#   inflating: MVSA_Single/data/9.txt
#   inflating: MVSA_Single/data/90.jpg
#   inflating: MVSA_Single/data/90.txt
#   inflating: MVSA_Single/data/900.jpg
#  extracting: MVSA_Single/data/900.txt
#   inflating: MVSA_Single/data/901.jpg
#   inflating: MVSA_Single/data/901.txt
#   inflating: MVSA_Single/data/902.jpg
#   inflating: MVSA_Single/data/902.txt
#   inflating: MVSA_Single/data/903.jpg
#   inflating: MVSA_Single/data/903.txt
#   inflating: MVSA_Single/data/904.jpg
#   inflating: MVSA_Single/data/904.txt
#   inflating: MVSA_Single/data/905.jpg
#  extracting: MVSA_Single/data/905.txt
#   inflating: MVSA_Single/data/906.jpg
#   inflating: MVSA_Single/data/906.txt
#   inflating: MVSA_Single/data/907.jpg
#   inflating: MVSA_Single/data/907.txt
#   inflating: MVSA_Single/data/908.jpg
#  extracting: MVSA_Single/data/908.txt
#   inflating: MVSA_Single/data/909.jpg
#   inflating: MVSA_Single/data/909.txt
#   inflating: MVSA_Single/data/91.jpg
#   inflating: MVSA_Single/data/91.txt
#   inflating: MVSA_Single/data/910.jpg
#   inflating: MVSA_Single/data/910.txt
#   inflating: MVSA_Single/data/911.jpg
#   inflating: MVSA_Single/data/911.txt
#   inflating: MVSA_Single/data/912.jpg
#   inflating: MVSA_Single/data/912.txt
#   inflating: MVSA_Single/data/913.jpg
#  extracting: MVSA_Single/data/913.txt
#   inflating: MVSA_Single/data/914.jpg
#   inflating: MVSA_Single/data/914.txt
#   inflating: MVSA_Single/data/915.jpg
#   inflating: MVSA_Single/data/915.txt
#   inflating: MVSA_Single/data/916.jpg
#   inflating: MVSA_Single/data/916.txt
#   inflating: MVSA_Single/data/917.jpg
#  extracting: MVSA_Single/data/917.txt
#   inflating: MVSA_Single/data/918.jpg
#   inflating: MVSA_Single/data/918.txt
#   inflating: MVSA_Single/data/919.jpg
#   inflating: MVSA_Single/data/919.txt
#   inflating: MVSA_Single/data/92.jpg
#   inflating: MVSA_Single/data/92.txt
#   inflating: MVSA_Single/data/920.jpg
#   inflating: MVSA_Single/data/920.txt
#   inflating: MVSA_Single/data/921.jpg
#  extracting: MVSA_Single/data/921.txt
#   inflating: MVSA_Single/data/922.jpg
#  extracting: MVSA_Single/data/922.txt
#   inflating: MVSA_Single/data/923.jpg
#  extracting: MVSA_Single/data/923.txt
#   inflating: MVSA_Single/data/924.jpg
#   inflating: MVSA_Single/data/924.txt
#   inflating: MVSA_Single/data/925.jpg
#  extracting: MVSA_Single/data/925.txt
#   inflating: MVSA_Single/data/926.jpg
#  extracting: MVSA_Single/data/926.txt
#   inflating: MVSA_Single/data/927.jpg
#   inflating: MVSA_Single/data/927.txt
#   inflating: MVSA_Single/data/928.jpg
#   inflating: MVSA_Single/data/928.txt
#   inflating: MVSA_Single/data/929.jpg
#   inflating: MVSA_Single/data/929.txt
#   inflating: MVSA_Single/data/93.jpg
#   inflating: MVSA_Single/data/93.txt
#   inflating: MVSA_Single/data/930.jpg
#   inflating: MVSA_Single/data/930.txt
#   inflating: MVSA_Single/data/931.jpg
#   inflating: MVSA_Single/data/931.txt
#   inflating: MVSA_Single/data/932.jpg
#   inflating: MVSA_Single/data/932.txt
#   inflating: MVSA_Single/data/933.jpg
#  extracting: MVSA_Single/data/933.txt
#   inflating: MVSA_Single/data/934.jpg
#   inflating: MVSA_Single/data/934.txt
#   inflating: MVSA_Single/data/935.jpg
#  extracting: MVSA_Single/data/935.txt
#   inflating: MVSA_Single/data/936.jpg
#  extracting: MVSA_Single/data/936.txt
#   inflating: MVSA_Single/data/937.jpg
#   inflating: MVSA_Single/data/937.txt
#   inflating: MVSA_Single/data/938.jpg
#   inflating: MVSA_Single/data/938.txt
#   inflating: MVSA_Single/data/939.jpg
#  extracting: MVSA_Single/data/939.txt
#   inflating: MVSA_Single/data/94.jpg
#   inflating: MVSA_Single/data/94.txt
#   inflating: MVSA_Single/data/940.jpg
#   inflating: MVSA_Single/data/940.txt
#   inflating: MVSA_Single/data/941.jpg
#  extracting: MVSA_Single/data/941.txt
#   inflating: MVSA_Single/data/942.jpg
#  extracting: MVSA_Single/data/942.txt
#   inflating: MVSA_Single/data/943.jpg
#   inflating: MVSA_Single/data/943.txt
#   inflating: MVSA_Single/data/944.jpg
#   inflating: MVSA_Single/data/944.txt
#   inflating: MVSA_Single/data/945.jpg
#   inflating: MVSA_Single/data/945.txt
#   inflating: MVSA_Single/data/946.jpg
#  extracting: MVSA_Single/data/946.txt
#   inflating: MVSA_Single/data/947.jpg
#   inflating: MVSA_Single/data/947.txt
#   inflating: MVSA_Single/data/948.jpg
#   inflating: MVSA_Single/data/948.txt
#   inflating: MVSA_Single/data/949.jpg
#   inflating: MVSA_Single/data/949.txt
#   inflating: MVSA_Single/data/95.jpg
#   inflating: MVSA_Single/data/95.txt
#   inflating: MVSA_Single/data/950.jpg
#   inflating: MVSA_Single/data/950.txt
#   inflating: MVSA_Single/data/951.jpg
#  extracting: MVSA_Single/data/951.txt
#   inflating: MVSA_Single/data/952.jpg
#   inflating: MVSA_Single/data/952.txt
#   inflating: MVSA_Single/data/953.jpg
#   inflating: MVSA_Single/data/953.txt
#   inflating: MVSA_Single/data/954.jpg
#   inflating: MVSA_Single/data/954.txt
#   inflating: MVSA_Single/data/955.jpg
#  extracting: MVSA_Single/data/955.txt
#   inflating: MVSA_Single/data/956.jpg
#   inflating: MVSA_Single/data/956.txt
#   inflating: MVSA_Single/data/957.jpg
#   inflating: MVSA_Single/data/957.txt
#   inflating: MVSA_Single/data/958.jpg
#  extracting: MVSA_Single/data/958.txt
#   inflating: MVSA_Single/data/959.jpg
#   inflating: MVSA_Single/data/959.txt
#   inflating: MVSA_Single/data/96.jpg
#   inflating: MVSA_Single/data/96.txt
#   inflating: MVSA_Single/data/960.jpg
#   inflating: MVSA_Single/data/960.txt
#   inflating: MVSA_Single/data/961.jpg
#   inflating: MVSA_Single/data/961.txt
#   inflating: MVSA_Single/data/962.jpg
#  extracting: MVSA_Single/data/962.txt
#   inflating: MVSA_Single/data/963.jpg
#  extracting: MVSA_Single/data/963.txt
#   inflating: MVSA_Single/data/964.jpg
#  extracting: MVSA_Single/data/964.txt
#   inflating: MVSA_Single/data/965.jpg
#   inflating: MVSA_Single/data/965.txt
#   inflating: MVSA_Single/data/966.jpg
#  extracting: MVSA_Single/data/966.txt
#   inflating: MVSA_Single/data/967.jpg
#   inflating: MVSA_Single/data/967.txt
#   inflating: MVSA_Single/data/968.jpg
#   inflating: MVSA_Single/data/968.txt
#   inflating: MVSA_Single/data/969.jpg
#  extracting: MVSA_Single/data/969.txt
#   inflating: MVSA_Single/data/97.jpg
#   inflating: MVSA_Single/data/97.txt
#   inflating: MVSA_Single/data/970.jpg
#   inflating: MVSA_Single/data/970.txt
#   inflating: MVSA_Single/data/971.jpg
#   inflating: MVSA_Single/data/971.txt
#   inflating: MVSA_Single/data/972.jpg
#   inflating: MVSA_Single/data/972.txt
#   inflating: MVSA_Single/data/973.jpg
#   inflating: MVSA_Single/data/973.txt
#   inflating: MVSA_Single/data/974.jpg
#   inflating: MVSA_Single/data/974.txt
#   inflating: MVSA_Single/data/975.jpg
#  extracting: MVSA_Single/data/975.txt
#   inflating: MVSA_Single/data/976.jpg
#   inflating: MVSA_Single/data/976.txt
#   inflating: MVSA_Single/data/977.jpg
#   inflating: MVSA_Single/data/977.txt
#   inflating: MVSA_Single/data/978.jpg
#   inflating: MVSA_Single/data/978.txt
#   inflating: MVSA_Single/data/979.jpg
#   inflating: MVSA_Single/data/979.txt
#   inflating: MVSA_Single/data/98.jpg
#  extracting: MVSA_Single/data/98.txt
#   inflating: MVSA_Single/data/980.jpg
#   inflating: MVSA_Single/data/980.txt
#   inflating: MVSA_Single/data/981.jpg
#   inflating: MVSA_Single/data/981.txt
#   inflating: MVSA_Single/data/982.jpg
#  extracting: MVSA_Single/data/982.txt
#   inflating: MVSA_Single/data/983.jpg
#   inflating: MVSA_Single/data/983.txt
#   inflating: MVSA_Single/data/984.jpg
#   inflating: MVSA_Single/data/984.txt
#   inflating: MVSA_Single/data/985.jpg
#   inflating: MVSA_Single/data/985.txt
#   inflating: MVSA_Single/data/986.jpg
#   inflating: MVSA_Single/data/986.txt
#   inflating: MVSA_Single/data/987.jpg
#   inflating: MVSA_Single/data/987.txt
#   inflating: MVSA_Single/data/988.jpg
#   inflating: MVSA_Single/data/988.txt
#   inflating: MVSA_Single/data/989.jpg
#   inflating: MVSA_Single/data/989.txt
#   inflating: MVSA_Single/data/99.jpg
#  extracting: MVSA_Single/data/99.txt
#   inflating: MVSA_Single/data/990.jpg
#   inflating: MVSA_Single/data/990.txt
#   inflating: MVSA_Single/data/991.jpg
#   inflating: MVSA_Single/data/991.txt
#   inflating: MVSA_Single/data/992.jpg
#  extracting: MVSA_Single/data/992.txt
#   inflating: MVSA_Single/data/993.jpg
#   inflating: MVSA_Single/data/993.txt
#   inflating: MVSA_Single/data/994.jpg
#   inflating: MVSA_Single/data/994.txt
#   inflating: MVSA_Single/data/995.jpg
#  extracting: MVSA_Single/data/995.txt
#   inflating: MVSA_Single/data/996.jpg
#  extracting: MVSA_Single/data/996.txt
#   inflating: MVSA_Single/data/997.jpg
#  extracting: MVSA_Single/data/997.txt
#   inflating: MVSA_Single/data/998.jpg
#  extracting: MVSA_Single/data/998.txt
#   inflating: MVSA_Single/data/999.jpg
#   inflating: MVSA_Single/data/999.txt
#   inflating: MVSA_Single/labelResultAll.txt

# %%
import os

# %%
img_names = []
text_transcriptions = []
for files in sorted(os.listdir("/content/MVSA_Single/data")):
  if files.endswith(".jpg"):
    img_names.append(files)
  else:
    file1 = open(os.path.join("/content/MVSA_Single/data",files),"rb")
    text_transcriptions.append(file1.readline())

# %%
# img_names

# %%
# text_transcriptions

# %%
import pandas as pd

# %%
df_ = pd.DataFrame(zip(img_names,text_transcriptions),columns = ['img_names','text_transcriptions'])

# %%
df = pd.read_csv("/content/MVSA_Single/labelResultAll.txt")

# %%
df.head()
# Out:
#       ID\ttext     image
# 0   1\tneutral  positive
# 1   2\tneutral  positive
# 2   3\tneutral  positive
# 3  4\tpositive  positive
# 4  5\tpositive  positive

# %%
df['ID'] = df['ID\ttext'].apply(lambda x :x.split('\t')[0])
df['text'] = df['ID\ttext'].apply(lambda x :x.split('\t')[1])
df.drop(columns = ['ID\ttext'],inplace = True)

# %%
df.head()
# Out:
#       image ID      text
# 0  positive  1   neutral
# 1  positive  2   neutral
# 2  positive  3   neutral
# 3  positive  4  positive
# 4  positive  5  positive

# %%
df['ID'] = df['ID'] + ".jpg"

# %%
df.head()
# Out:
#       image     ID      text
# 0  positive  1.jpg   neutral
# 1  positive  2.jpg   neutral
# 2  positive  3.jpg   neutral
# 3  positive  4.jpg  positive
# 4  positive  5.jpg  positive

# %%
df.columns = ['image_label','img_names','text_labels']

# %%
df_.head()
# Out:
#   img_names                                text_transcriptions
# 0     1.jpg  b'How I feel today #legday #jelly #aching #gym...
# 1    10.jpg  b'@ArrivaTW absolute disgrace two carriages fr...
# 2   100.jpg  b"This is my Valentine's from 1 of my nephews....
# 3  1000.jpg  b"betterfeelingfilms: RT via Instagram: First ...
# 4  1001.jpg  b"Zoe's first love #Rattled @JohnnyHarper15 \r\n"

# %%
df_final = pd.merge(df, df_, on="img_names")

# %%
df_final.shape
# Out:
# (4869, 4)

# %%
df_final.head()
# Out:
#   image_label  ...                                text_transcriptions
# 0    positive  ...  b'How I feel today #legday #jelly #aching #gym...
# 1    positive  ...  b'grattis min griskulting!!!???? va bara tvung...
# 2    positive  ...  b'RT @polynminion: The moment I found my favou...
# 3    positive  ...  b'#escort We have a young and energetic team a...
# 4    positive  ...  b'RT @chrisashaffer: Went to SSC today to be a...
#
# [5 rows x 4 columns]

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.16.2-py3-none-any.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 14.1 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.5)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 61.8 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting sacremoses
#   Downloading sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 61.6 MB/s
# Collecting tokenizers!=0.11.3,>=0.10.1
#   Downloading tokenizers-0.11.5-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 37.7 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.4.2)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 6.9 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.7.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.4.0 pyyaml-6.0 sacremoses-0.0.47 tokenizers-0.11.5 transformers-4.16.2

# %%
import pandas as pd

# %%
df = df_final

# %%
from transformers import (
   AutoConfig,
   AutoTokenizer,
   TFAutoModelForSequenceClassification,
   AdamW,
   glue_convert_examples_to_features
)
import tensorflow as tf
import tensorflow_datasets as tfds
import json

# %%
import transformers
from transformers import BertModel, BertTokenizer, AdamW, get_linear_schedule_with_warmup
import torch
import numpy as np
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from collections import defaultdict
from textwrap import wrap
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
sns.set(style='whitegrid', palette='muted', font_scale=1.2)
HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#ADFF02", "#8F00FF"]
sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))
rcParams['figure.figsize'] = 12, 8
# RANDOM_SEED = 42
# np.random.seed(RANDOM_SEED)
# torch.manual_seed(RANDOM_SEED)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 6006701117333073717
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15371862016
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 15883649190058919185
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %%
from torchvision import datasets, transforms

# %%
from PIL import Image
import requests
from transformers import VisionTextDualEncoderModel, VisionTextDualEncoderProcessor, ViTFeatureExtractor, BertTokenizer

# %%
from transformers import RobertaTokenizer
from transformers import DeiTFeatureExtractor, DeiTModel

# %%
tokenizer = RobertaTokenizer.from_pretrained("roberta-base")
feature_extractor = DeiTFeatureExtractor.from_pretrained("facebook/deit-base-distilled-patch16-224")
processor = VisionTextDualEncoderProcessor(feature_extractor, tokenizer)
# Out:
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/287 [00:00<?, ?B/s]

# %%
# tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
# feature_extractor = ViTFeatureExtractor.from_pretrained("google/vit-base-patch16-224")
# Out:
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/160 [00:00<?, ?B/s]

# %%
tokenizer.model_max_length = 96

# %%
tokenizer
# Out:
# PreTrainedTokenizer(name_or_path='bert-base-uncased', vocab_size=30522, model_max_len=96, is_fast=False, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'})

# %%
processor = VisionTextDualEncoderProcessor(feature_extractor, tokenizer)

# %%
_transforms = transforms.Compose(
    [
        transforms.Resize((448, 448)),
        # transforms.RandomResizedCrop(224),
        # transforms.RandomHorizontalFlip(),
        # transforms.ToTensor()
    ]
    
)

# %%
# processor()

# %%
class GPReviewDataset(Dataset):
  def __init__(self, Text,image, Label, processor):
    self.Text = Text
    self.image = image
    self.Label = Label
    # self.tokenizer = tokenizer
    # self.feature_extractor = feature_extractor
    self.processor = processor
    # self.max_len = max_len
  def __len__(self):
    return len(self.Text)
  def __getitem__(self, item):
    img_path = self.image[item]
    img = Image.open("/content/MVSA_Single/data/"+img_path).convert('RGB')
    img_transformed = _transforms(img)
    Text = str(self.Text[item])
    Label = self.Label[item]
    inputs = processor(text=Text, images=img_transformed, return_tensors="pt", padding='max_length',truncation=True)
    # inputs = inputs.squeeze(0)
    # print(Text)
    # print(img_transformed.shape)
    # print(Label.shape)
    # print(inputs.input_ids.shape)
    # print(Text)
    # print(Text)
    # print(inputs.pixel_values.shape)
    return {
      'input_ids': inputs.input_ids.squeeze(0),
      'attention_mask': inputs.attention_mask.squeeze(0),
      'pixel_values' : inputs.pixel_values.squeeze(0),
      'Label': torch.tensor(Label, dtype=torch.long)
    }

# %%
df
# Out:
#      image_label  ...                                text_transcriptions
# 0       positive  ...  b'How I feel today #legday #jelly #aching #gym...
# 1       positive  ...  b'grattis min griskulting!!!???? va bara tvung...
# 2       positive  ...  b'RT @polynminion: The moment I found my favou...
# 3       positive  ...  b'#escort We have a young and energetic team a...
# 4       positive  ...  b'RT @chrisashaffer: Went to SSC today to be a...
# ...          ...  ...                                                ...
# 4864    positive  ...  b'http://t.co/Y4ZrSmq2KB http://t.co/L\xa1\xad...
# 4865     neutral  ...  b'YES! #sinful #food #freefrom #glutenfree #su...
# 4866    positive  ...  b'RT @bookmyshow: #Disney\'s lies - "Every day...
# 4867    positive  ...  b'RT @MUBMI: TWO MORE DAYS to submit your apps...
# 4868    positive  ...  b"RT @khununeos: khun was literally me wheneve...
#
# [4869 rows x 4 columns]

# %%
df = df.drop(columns = ['image_label'])

# %%
df.columns = ['file_name','label','Text Transcription']

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
import re

# %%
df['label'] = le.fit_transform(df['label'])

# %%
df_train, df_val = train_test_split(
  df,
  test_size=0.20,
  stratify = df.label.values,
  random_state=42
)
df_val, df_test = train_test_split(
  df_val,
  test_size=0.50,
  stratify = df_val.label.values,
  random_state=42
)


df_train.shape, df_val.shape,df_test.shape
# Out:
# ((3895, 3), (487, 3), (487, 3))

# %%
le.classes_
# Out:
# array(['negative', 'neutral', 'positive'], dtype=object)

# %%
def create_data_loader(df, processor, batch_size):
  ds = GPReviewDataset(
    Text=df['Text Transcription'].to_numpy(),
    image = df.file_name.to_numpy(),
    Label=df.label.to_numpy(),
    processor=processor
  )
  return DataLoader(
    ds,
    batch_size=batch_size,
    num_workers=0
  )

# %%
BATCH_SIZE = 8
train_data_loader = create_data_loader(df_train, processor, BATCH_SIZE)
val_data_loader = create_data_loader(df_val, processor, BATCH_SIZE)
test_data_loader = create_data_loader(df_test, processor, BATCH_SIZE)

# %%
class SentimentClassifier(nn.Module):
  def __init__(self, n_classes):
    super(SentimentClassifier, self).__init__()
    self.bert = VisionTextDualEncoderModel.from_vision_text_pretrained("facebook/deit-base-distilled-patch16-224", "roberta-base")
    
    self.drop = nn.Dropout(p=0.30)
    self.out = nn.Linear(1024, n_classes)
  def forward(self, input_ids, attention_mask,pixel_values):
    outputs = self.bert(
      input_ids=input_ids,
      attention_mask=attention_mask,
      pixel_values=pixel_values,
      return_dict=True)
    output = self.drop(torch.cat((outputs.text_embeds,outputs.image_embeds),1))
    return self.out(output)

# %%
class_names = le.classes_

# %%
modell = SentimentClassifier(len(class_names))
modell = modell.to(device)
# Out:
# Downloading:   0%|          | 0.00/68.0k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/333M [00:00<?, ?B/s]
# Some weights of the model checkpoint at facebook/deit-base-distilled-patch16-224 were not used when initializing DeiTModel: ['cls_classifier.weight', 'distillation_classifier.bias', 'cls_classifier.bias', 'distillation_classifier.weight']
# - This IS expected if you are initializing DeiTModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DeiTModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DeiTModel were not initialized from the model checkpoint at facebook/deit-base-distilled-patch16-224 and are newly initialized: ['deit.pooler.dense.bias', 'deit.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading:   0%|          | 0.00/478M [00:00<?, ?B/s]
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# The projection layer and logit scale weights `['visual_projection.weight', 'text_projection.weight', 'logit_scale']` are newly initialized. You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
EPOCHS = 3
optimizer = AdamW(modell.parameters(), lr=2e-5, correct_bias=True)
total_steps = len(train_data_loader) * EPOCHS
scheduler = get_linear_schedule_with_warmup(
  optimizer,
  num_warmup_steps=0,
  num_training_steps=total_steps
)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use thePyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,

# %%
loss_fn = nn.CrossEntropyLoss().to(device)

# %%
def train_epoch(
  modell,
  data_loader,
  loss_fn,
  optimizer,
  device,
  scheduler,
  n_examples):
  modell = modell.train()
  losses = []
  correct_predictions = 0
  for d in data_loader:
    input_ids = d["input_ids"].to(device)
    attention_mask = d["attention_mask"].to(device)
    pixel_values = d['pixel_values'].to(device)
    Label = d["Label"].to(device)
    outputs = modell(
      input_ids=input_ids,
      attention_mask=attention_mask,
      pixel_values = pixel_values
    )
    
    _, preds = torch.max(outputs, dim=1)
    loss = loss_fn(outputs, Label)
    correct_predictions += torch.sum(preds == Label)
    losses.append(loss.item())
    loss.backward()
    nn.utils.clip_grad_norm_(modell.parameters(), max_norm=1.0)
    optimizer.step()
    scheduler.step()
    optimizer.zero_grad()
  return correct_predictions.double() / n_examples, np.mean(losses)

# %%
def eval_model(modell, data_loader, loss_fn, device, n_examples):
  modell = modell.eval()
  losses = []
  correct_predictions = 0
  with torch.no_grad():
    for d in data_loader:
      input_ids = d["input_ids"].to(device)
      attention_mask = d["attention_mask"].to(device)
      pixel_values = d['pixel_values'].to(device)
      Label = d["Label"].to(device)
      outputs = modell(
        input_ids=input_ids,
        attention_mask=attention_mask,
        pixel_values = pixel_values
      )
      _, preds = torch.max(outputs, dim=1)
      loss = loss_fn(outputs, Label)
      correct_predictions += torch.sum(preds == Label)
      losses.append(loss.item())
  return correct_predictions.double() / n_examples, np.mean(losses)

# %%
# %%time
history = defaultdict(list)
best_accuracy = 0
for epoch in range(EPOCHS):
  print(f'Epoch {epoch + 1}/{EPOCHS}')
  print('-' * 10)
  train_acc, train_loss = train_epoch(
    modell,
    train_data_loader,
    loss_fn,
    optimizer,
    device,
    scheduler,
    len(df_train)
  )
  print(f'Train loss {train_loss} accuracy {train_acc}')
  val_acc, val_loss = eval_model(
    modell,
    val_data_loader,
    loss_fn,
    device,
    len(df_val)
  )

  print(f'Val   loss {val_loss} accuracy {val_acc}')
  print()
  history['train_acc'].append(train_acc)
  history['train_loss'].append(train_loss)
  history['val_acc'].append(val_acc)
  history['val_loss'].append(val_loss)
  if val_acc > best_accuracy:
    torch.save(modell.state_dict(), 'best_model_state.bin')
    best_accuracy = val_acc
# Out:
# Epoch 1/3
# ----------
# Train loss 0.9675478978078713 accuracy 0.6179717586649551
# Val   loss 0.9060529069822343 accuracy 0.7063655030800822
#
# Epoch 2/3
# ----------
# Train loss 0.8424194276455247 accuracy 0.7702182284980745
# Val   loss 0.8586521168224147 accuracy 0.7268993839835729
#
# Epoch 3/3
# ----------
# Train loss 0.7631586244218893 accuracy 0.8254172015404365
# Val   loss 0.8584473729133606 accuracy 0.7145790554414785
#
# CPU times: user 8min 7s, sys: 1min 38s, total: 9min 45s
# Wall time: 9min 53s

# %%
def get_predictions(model, data_loader):
  model = model.eval()
  
  id = []
  ip = []
  predictions = []
  prediction_probs = []
  real_values = []

  with torch.no_grad():
    for d in data_loader:

      # texts = d["Text"]
      input_ids = d["input_ids"].to(device)
      attention_mask = d["attention_mask"].to(device)
      pixel_values = d['pixel_values'].to(device)
      targets = d["Label"].to(device)

      outputs = model(
        input_ids=input_ids,
        attention_mask=attention_mask,
        pixel_values = pixel_values
      )
      _, preds = torch.max(outputs, dim=1)
      # ids = d['ID']
      # ips = d['img_path']
      # probs = F.softmax(outputs, dim=1)
      
      # review_texts.extend(texts)
      predictions.extend(preds)
      # id.extend(ids)
      # ip.extend(ips)
      # prediction_probs.extend(probs)
      real_values.extend(targets)

  predictions = torch.stack(predictions).cpu()
  # idss = id
  # ipss = ip
  # prediction_probs = torch.stack(prediction_probs).cpu()
  real_values = torch.stack(real_values).cpu()
  return real_values,predictions

# %%
real_values,y_pred = get_predictions(
  modell,
  test_data_loader
)

# %%
print(classification_report(real_values, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.72      0.68       122
#            1       0.77      0.74      0.76       192
#            2       0.77      0.75      0.76       173
#
#     accuracy                           0.74       487
#    macro avg       0.73      0.74      0.73       487
# weighted avg       0.74      0.74      0.74       487

# %%
confusionmatrix = confusion_matrix(real_values, y_pred)
plt.figure(figsize = (16, 16))
sns.heatmap(confusionmatrix, cmap = 'Blues', annot = True, cbar = True)

print(classification_report(real_values, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.72      0.68       122
#            1       0.77      0.74      0.76       192
#            2       0.77      0.75      0.76       173
#
#     accuracy                           0.74       487
#    macro avg       0.73      0.74      0.73       487
# weighted avg       0.74      0.74      0.74       487
